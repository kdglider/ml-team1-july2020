# %%
import pandas as pd
import numpy as np
import copy
import ast
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# %run classifier_NB.ipynb
# %run classifier_SVM.ipynb

# code taken from https://medium.com/@bedigunjit/simple-guide-to-text-classification-nlp-using-svm-and-naive-bayes-with-python-421db3a72d34

class TagPredictor:
    def __init__(self, classifier, corpus, categories):
        self.classifier = classifier
        self.corpus = corpus
        self.categories = categories

        np.random.seed(500)

        print("Initialized TagPredictor")
        
        
    def train(self):
        print("Started training")
        
        # Filter out unused categories
        self.corpus['Tags'] = self.corpus['Tags'].map(lambda tags : list(filter(lambda tag : tag in categories, ast.literal_eval(tags))))
        
        # Transform tags to multilabel format
        self.mlb = MultiLabelBinarizer()
        Y_matrix = self.mlb.fit_transform(self.corpus['Tags'])
        #np.set_printoptions(threshold=np.inf)
        #print(matrix[0])
        
        train, test, Train_Y, Test_Y = train_test_split(self.corpus, Y_matrix, test_size=0.3, shuffle=True)
        Train_X = train['text_final']
        Test_X = test['text_final']
        #print(Train_X)
        #print(Train_Y)
        

        self.Tfidf_vect = TfidfVectorizer(max_features=5000)
        self.Tfidf_vect.fit(self.corpus['text_final'])
        Train_X_Tfidf = self.Tfidf_vect.transform(Train_X)
        Test_X_Tfidf = self.Tfidf_vect.transform(Test_X)

        self.model = self.classifier()
        self.model.train(Train_X_Tfidf, Train_Y, Test_X_Tfidf, Test_Y)
        
        print("Finished training")
        
        
    def predict(self, df):
        # return predictions_df, confidence_level
        X = df['text_final']
        X_Tfidf = self.Tfidf_vect.transform(X)
        matrix = self.model.predict(X_Tfidf)
        labels = self.mlb.inverse_transform(matrix)
        return labels
        
"""
def main():
    nb = Classifier_NB()
    svm = Classifier_SVM()

    # read the data frame from csv (change the path for your local machine)
    corpus = pd.read_csv(r"/Users/maxim/dev/STEM-Away/ml-team1-july2020/sandbox/webscraper/StackOverflow.csv", engine='python')
    print(corpus.shape)
    print(corpus.columns)
    
    # tagPredictor = TagPredictor(nb, corpus)
    #tagPredictor = TagPredictor(svm, corpus)

    #tagPredictor.preprocess()
    #tagPredictor.train()

if __name__ == '__main__':
    main()
"""
# Out:
# '\ndef main():\n    nb = Classifier_NB()\n    svm = Classifier_SVM()\n\n    # read the data frame from csv (change the path for your local machine)\n    corpus = pd.read_csv(r"/Users/maxim/dev/STEM-Away/ml-team1-july2020/sandbox/webscraper/StackOverflow.csv", engine=\'python\')\n    print(corpus.shape)\n    print(corpus.columns)\n    \n    # tagPredictor = TagPredictor(nb, corpus)\n    #tagPredictor = TagPredictor(svm, corpus)\n\n    #tagPredictor.preprocess()\n    #tagPredictor.train()\n\nif __name__ == \'__main__\':\n    main()\n'

# %%
# Preprocess

def preprocess(df):
        print("Started preprocessing")

        # Step - a : Remove blank rows if any.
        df['Topic Title'].dropna(inplace=True)
        # Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
        df['Topic Title'] = [entry.lower() for entry in df['Topic Title']]
        # Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
        df['Topic Title'] = [word_tokenize(entry) for entry in df['Topic Title']]
        # Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
        # WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
        tag_map = defaultdict(lambda : wn.NOUN)
        tag_map['J'] = wn.ADJ
        tag_map['V'] = wn.VERB
        tag_map['R'] = wn.ADV
        for index,entry in enumerate(df['Topic Title']):
            # Declaring Empty List to store the words that follow the rules for this step
            Final_words = []
            # Initializing WordNetLemmatizer()
            word_Lemmatized = WordNetLemmatizer()
            # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
            for word, tag in pos_tag(entry):
                # Below condition is to check for Stop words and consider only alphabets
                if word not in stopwords.words('english') and word.isalpha():
                    word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                    Final_words.append(word_Final)
            # The final processed set of words for each iteration will be stored in 'text_final'
            df.loc[index,'text_final'] = str(Final_words)

        print("Finished preprocessing")
        
        return df

# %%
# Main

# read the data frame from csv (change the path for your local machine)
corpus = pd.read_csv(r"/Users/maxim/dev/STEM-Away/ml-team1-july2020/sandbox/webscraper/StackOverflow.csv", engine='python')
corpus = preprocess(corpus)
# Out:
# Started preprocessing
# Finished preprocessing

# %%
categories = ['nlp', 'nltk', 'bert', 'word-embedding','text-classification','data-augmentation', 'sentiment-analysis', 'tf-idf', 'scikit-learn', 'feature-extraction', 'text-mining']
    
# tagPredictor = TagPredictor(Classifier_NB, corpus, categories)
tagPredictor = TagPredictor(Classifier_SVM, corpus, categories)
# Out:
# Initialized TagPredictor

# %%
tagPredictor.train()
# Out:
# Started training
# Running SVM Classifier
# SVM Accuracy Score ->  28.42548076923077
# Finished training

# %%
corpus = pd.read_csv(r"/Users/maxim/dev/STEM-Away/ml-team1-july2020/sandbox/webscraper/StackOverflow.csv", engine='python')
test_df = preprocess(corpus)
tagPredictor.predict(test_df)
# Out:
# Started preprocessing
# Finished preprocessing

# %%
# Out:
#       Unnamed: 0                                        Topic Title  \
# 0              0  [valueerror, using, fasttext, trained, bin, mo...
# 1              1  [rnn, language, model, in, pytorch, predicting...
# 2              2  [add, additional, layers, to, the, huggingface...
# 3              3  [topic, score/weight, varies, for, seen, text,...
# 4              4  [how, should, i, load, a, large, nlp, file, in...
# ...          ...                                                ...
# 5541        5541  [extract, variations, of, a, string, from, r, ...
# 5542        5542  [how, to, build, a, subject-verb-object, extra...
# 5543        5543  [naive, bayes, model, not, predicting, anythin...
# 5544        5544      [how, to, read, csv, file, for, text, mining]
# 5545        5545  [keep, only, sentences, in, corpus, that, cont...
#
#                                                    Tags  \
# 0     ['machine-learning', 'nlp', 'unsupervised-lear...
# 1     ['machine-learning', 'nlp', 'pytorch', 'recurr...
# 2     ['python', 'tensorflow', 'keras', 'nlp', 'hugg...
# 3        ['python-3.x', 'nlp', 'lda', 'topic-modeling']
# 4     ['amazon-web-services', 'aws-lambda', 'nlp', '...
# ...                                                 ...
# 5541                        ['r', 'nlp', 'text-mining']
# 5542  ['python-2.7', 'structure', 'text-mining', 'sp...
# 5543                 ['r', 'text-mining', 'naivebayes']
# 5544                        ['r', 'csv', 'text-mining']
# 5545  ['r', 'text-mining', 'corpus', 'text-analysis'...
#
#                                         Leading Comment  \
# 0     I trained two fastText models supervised with ...
# 1     I am attempting to create a word-level languag...
# 2     I want to add additional Dense layer after pre...
# 3     for an unseen text, we can find out the topic ...
# 4     I have a NLP program which uses Spacy to load ...
# ...                                                 ...
# 5541  I have list of keywordsI have a column which h...
# 5542  I have a pandas data frame object with one tex...
# 5543  My dataset looks like the following, and I fol...
# 5544  I will be using tm for text mining purpose.How...
# 5545  I have a corpus with txt documents. From these...
#
#                                              text_final
# 0     ['valueerror', 'use', 'fasttext', 'trained', '...
# 1     ['rnn', 'language', 'model', 'pytorch', 'predi...
# 2     ['add', 'additional', 'layer', 'huggingface', ...
# 3             ['topic', 'varies', 'see', 'text', 'lda']
# 4            ['load', 'large', 'nlp', 'file', 'lambda']
# ...                                                 ...
# 5541  ['extract', 'variation', 'string', 'r', 'column']
# 5542         ['build', 'extraction', 'model', 'python']
# 5543  ['naive', 'bayes', 'model', 'predict', 'anythi...
# 5544          ['read', 'csv', 'file', 'text', 'mining']
# 5545  ['keep', 'sentence', 'corpus', 'contain', 'spe...
#
# [5546 rows x 5 columns]
# [(),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('scikit-learn',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('text-mining',),
#  (),
#  ('nlp',),
#  (),
#  ('sentiment-analysis',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('bert',),
#  (),
#  ('nlp',),
#  ('bert', 'nlp'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nltk',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('feature-extraction',),
#  (),
#  (),
#  ('bert',),
#  ('nlp',),
#  ('bert', 'nlp'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('text-classification',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'word-embedding'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp', 'nltk'),
#  (),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('bert', 'nlp', 'word-embedding'),
#  (),
#  (),
#  ('scikit-learn',),
#  (),
#  (),
#  ('bert', 'nlp'),
#  (),
#  (),
#  (),
#  (),
#  ('text-classification',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('text-mining',),
#  (),
#  (),
#  ('bert',),
#  (),
#  ('text-classification',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp', 'word-embedding'),
#  ('nlp',),
#  ('scikit-learn',),
#  (),
#  (),
#  ('feature-extraction', 'text-classification'),
#  ('nlp',),
#  (),
#  ('bert', 'sentiment-analysis'),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'sentiment-analysis'),
#  (),
#  (),
#  ('bert', 'nlp'),
#  ('nlp',),
#  ('nlp', 'word-embedding'),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('text-mining',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'scikit-learn'),
#  (),
#  ('bert',),
#  (),
#  (),
#  ('nlp',),
#  ('sentiment-analysis',),
#  ('nlp', 'nltk'),
#  ('nlp',),
#  (),
#  ('nlp', 'word-embedding'),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('text-classification',),
#  (),
#  ('text-mining',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('word-embedding',),
#  (),
#  (),
#  ('sentiment-analysis',),
#  (),
#  ('nlp',),
#  (),
#  ('text-mining',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('scikit-learn',),
#  ('nlp',),
#  ('nlp',),
#  ('bert',),
#  ('nlp', 'word-embedding'),
#  ('bert',),
#  (),
#  ('nlp',),
#  (),
#  ('bert',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp', 'word-embedding'),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('word-embedding',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp', 'word-embedding'),
#  ('word-embedding',),
#  ('nlp',),
#  (),
#  ('scikit-learn',),
#  ('nlp',),
#  ('bert',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('sentiment-analysis',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('feature-extraction', 'nlp'),
#  ('nlp',),
#  ('word-embedding',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('tf-idf',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('bert', 'word-embedding'),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('text-classification',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('data-augmentation',),
#  ('bert', 'nlp', 'sentiment-analysis'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('scikit-learn',),
#  ('bert', 'nlp'),
#  (),
#  (),
#  ('scikit-learn',),
#  ('nlp',),
#  ('word-embedding',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('word-embedding',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('tf-idf',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('tf-idf',),
#  (),
#  ('nlp',),
#  ('word-embedding',),
#  ('nlp', 'nltk'),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('sentiment-analysis',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp', 'text-classification'),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp', 'word-embedding'),
#  ('scikit-learn',),
#  ('nlp', 'nltk'),
#  (),
#  (),
#  ('nlp', 'sentiment-analysis'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  ('scikit-learn',),
#  ('sentiment-analysis',),
#  ('sentiment-analysis',),
#  (),
#  ('nlp',),
#  ('nlp', 'word-embedding'),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('bert', 'nlp', 'word-embedding'),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('sentiment-analysis',),
#  (),
#  ('nlp',),
#  ('word-embedding',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('bert',),
#  (),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp', 'word-embedding'),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp', 'text-classification'),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp', 'nltk'),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nltk',),
#  ('text-classification',),
#  (),
#  ('nlp',),
#  ('sentiment-analysis',),
#  ('nlp',),
#  ('bert',),
#  ('nlp', 'tf-idf'),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('bert', 'nlp'),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('bert', 'nlp'),
#  (),
#  (),
#  (),
#  ('text-classification',),
#  ('nlp',),
#  ('tf-idf',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp', 'text-classification'),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('bert', 'nlp'),
#  ('nlp',),
#  ('nlp',),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'word-embedding'),
#  ('nlp',),
#  ('scikit-learn',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  ('feature-extraction',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nlp',),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('bert', 'nlp'),
#  (),
#  ('nlp',),
#  ('bert',),
#  ('nlp',),
#  ('word-embedding',),
#  ('word-embedding',),
#  (),
#  ('nlp', 'text-classification'),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('scikit-learn',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nlp',),
#  (),
#  ('nltk', 'sentiment-analysis'),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  (),
#  ('sentiment-analysis',),
#  (),
#  (),
#  ('text-classification',),
#  ('nltk',),
#  (),
#  ('sentiment-analysis',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk', 'text-classification'),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk', 'sentiment-analysis'),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  (),
#  ('sentiment-analysis',),
#  (),
#  (),
#  (),
#  ('text-classification',),
#  (),
#  (),
#  (),
#  ('sentiment-analysis',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('scikit-learn',),
#  (),
#  (),
#  ('sentiment-analysis',),
#  ('text-mining',),
#  ('sentiment-analysis',),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nlp', 'nltk'),
#  ('nltk', 'sentiment-analysis'),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('feature-extraction',),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  (),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('text-classification',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('sentiment-analysis',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  ('nlp',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  ('sentiment-analysis',),
#  (),
#  (),
#  ('nltk',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nltk',),
#  ('nltk',),
#  ('nlp',),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  ('nlp',),
#  ('scikit-learn',),
#  (),
#  (),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('scikit-learn', 'tf-idf'),
#  ('nltk',),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('sentiment-analysis',),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  (),
#  (),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nlp', 'nltk'),
#  ('sentiment-analysis',),
#  ('nlp',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('sentiment-analysis',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  ('nlp',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nlp',),
#  (),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp', 'nltk'),
#  (),
#  (),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  (),
#  ('nltk',),
#  ('nlp',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  (),
#  ('nltk',),
#  ('nlp', 'nltk'),
#  ('nlp', 'nltk'),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  (),
#  ('nlp',),
#  (),
#  (),
#  ('nlp',),
#  (),
#  ('sentiment-analysis',),
#  (),
#  ('sentiment-analysis',),
#  ('nltk',),
#  ('nlp', 'nltk'),
#  (),
#  (),
#  ('nlp',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nlp', 'nltk'),
#  ('nltk',),
#  ('nltk',),
#  (),
#  ('nltk',),
#  ('nltk',),
#  (),
#  (),
#  ('nlp', 'nltk'),
#  ('nlp',),
#  ('nlp',),
#  ('nlp',),
#  ('nlp', 'nltk'),
#  (),
#  (),
#  ('nltk',),
#  (),
#  ...]
